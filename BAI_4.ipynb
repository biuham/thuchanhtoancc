# %% [markdown]
# <a href="https://colab.research.google.com/github/biuham/thuchanhtoancc/blob/main/BAI_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CHƯƠNG **4**

# %% [markdown]
# # thuc hanh 1: Chia khoảng dữ liệu

# %%
import numpy as np
mienchia = np.linspace(0,2,11)
mienchia
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ])

# %% [markdown]
# # thuc hanh 2: Vẽ các đồ thị

# %%
import numpy as np
import matplotlib.pyplot as plt

fs = [1,2,4]
all_time = np.linspace(0,2,200)
t = all_time[:100]

for f in fs:
  y = np.sin(2 * np.pi * f * t)
  plt.plot(t, y, label = '{} Hz'.format(f))

plt.legend()
import os
plt.savefig('basic_python.pdf')
plt.show()

# %% [markdown]
# **Gỉai pháp hướng đối tượng: Vẽ các hình như là các đối tượng "con" của plt:**

# %%
fig, ax = plt.subplots()
for f in fs:
  y = np.sin(2 * np.pi * f * t)
  ax.plot(t, y, label='{} Hz'.format(f))

# %% [markdown]
# **Gỉai pháp hướng máy trạng thái: Vẽ các hình trực tiếp lên trê đối tượng plt:**

# %%
for i in fs:
  y = np.sin(2 * np.pi * f * t)
  plt.plot(t, y, label='{} Hz'.format(f))

# %% [markdown]
# # thuc hanh 3: Xây dựng chương trình hướng đối tượng

# %% [markdown]
# Cách 1:

# %%
import numpy as np
import matplotlib.pyplot as plt

fs = [1,2,4]
all_time = np.linspace(0, 2, 200)
t = all_time[:100]

fig, ax = plt.subplots()
for f in fs:
  y = np.sin(2 * np.pi * f * t)
  ax.plot(t, y, label='{} Hz'.format(f))

plt.legend()
import os
plt.savefig('basics_python.pdf')
plt.show()

# %% [markdown]
# **Cách 2:**

# %%
import numpy as np
import matplotlib.pyplot as plt

fs = [1, 2, 4]
all_time = np.linspace(0, 2, 200)
t = all_time[:100]

for f in fs:
  y = np.sin(2 * np.pi * f * t)
  plt.plot(t, y, label='{} Hz'.format(f))
plt.legend()
import os
plt.savefig('basics_python.pdf')
plt.show()

# %% [markdown]
# **thuc hanh 4: Minh họa cơ bản về hàm lambda**

# %%
def f (x) : return x**2

print (f(8))
# Out:
# 64

# %%
g = lambda x: x**2

print (g(8))
# Out:
# 64

# %% [markdown]
# **thuc hanh 5: Tính thuế theo từng khi vực**

# %%
def thue(phan_tram): return lambda x: x * phan_tram

hcm = thue(0.012)
hn = thue(0.01)

# %%
hcm(1000000)
# Out:
# 12000.0

# %%
hn(1000000)
# Out:
# 10000.0

# %% [markdown]
# **thuc hanh 6: Biểu diễn cài đặt phương pháp hình thang với hàm lambda**

# %%
hinhthang = lambda f, a, b: (b-a)*(f(a)+f(b))/2
from math import exp
hinhthang(exp,0, 1)
# Out:
# 1.8591409142295225

# %%
def hai_x(x):
  return 2*x


hinhthang(hai_x, 1, 2)
# Out:
# 3.0

# %% [markdown]
# **thuc hanh 7: Xây dựng hàm tính tích phân cho e^x bằng phương pháp hình thang**

# %%
'''
Ham tinh theo luat hinh thang
cho ham(x) tu [trai, phai]
'''

def traprule(ham, trai , phai):
  return (phai-trai)*(ham(trai) + ham(phai))/2


import math
S = "Bieu thuc can tinh tich phan la e^x"
print(S + '[a,b]')
A = float(input('Nhap a: '))
B = float(input('Nhap b: '))
Y = traprule(math.exp, A, B)
print(S + '[%.1E,%.1E]:' % (A, B))
print('Gia tri xap xi :%.15E' % Y)
E = math.exp(B) - math.exp(A)
print('Gia tri chinh xac : %.15E' % E)
# Out:
# Bieu thuc can tinh tich phan la e^x[a,b]
# Nhap a: 0
# Nhap b: 1
# Bieu thuc can tinh tich phan la e^x[0.0E+00,1.0E+00]:
# Gia tri xap xi :1.859140914229523E+00
# Gia tri chinh xac : 1.718281828459045E+00

# %% [markdown]
# **thuc hanh 8: Viết các lệnh sau và thực hi cùng lúc trong tập scipy_in.py:**

# %%
import scipy
from sympy import *
import sys
sys.displathook = pprint
x = Symbol('x')
bt1 = integrate(x**2 + x + 1,x)
pprint (bt1)
bt2 = integrate(x/(x**2+2*x+1),x)
pprint (bt2)
bt3 = integrate(x**2 * exp(x) * cos(x),x)
pprint (bt3)
bt4 = integrate(exp(-x**2)*erf(x),x)
pprint (bt4)
# Out:
#  3    2
# x    x
# ── + ── + x
# 3    2
#                1
# log(x + 1) + ─────
#              x + 1
#  2  x           2  x                         x           x
# x ⋅ℯ ⋅sin(x)   x ⋅ℯ ⋅cos(x)      x          ℯ ⋅sin(x)   ℯ ⋅cos(x)
# ──────────── + ──────────── - x⋅ℯ ⋅sin(x) + ───────── - ─────────
#      2              2                           2           2
#       2
# √π⋅erf (x)
# ──────────
#     4

# %% [markdown]
# **thuc hanh 9: Tính tích phân đơn giản**

# %%
from sympy import Integral, Symbol
x = Symbol('x')
k = Symbol('k')
Integral(k*x, x)
# Out:
# Integral(k*x, x)

# %%
Integral(k*x, x).doit()
# Out:
# k*x**2/2

# %% [markdown]
# **thuc hanh 10: Tính tích phân đơn giản**

# %%
Integral(k*x, (x, 0 ,2)).doit()
# Out:
# 2*k

# %%
F = Integral(k*x, x).doit()
pprint(F)
# Out:
#    2
# k⋅x
# ────
#  2

# %% [markdown]
# **thuc hanh 11: Tính tích phân đơn giản**

# %%
Integral(k*x, (x, 0, 2)).doit()
# Out:
# 2*k

# %% [markdown]
# **thuc hanh 12: Tích tính phân đơn giản**

# %%
from sympy import Integral, Symbol
x = Symbol('x')
Integral(x, (x, 2, 4)).doit()
# Out:
# 6

# %% [markdown]
# **thuc hanh 13: Tính tích phân hàm mật độ xác suất**

# %%
from sympy import Symbol, exp, sqrt, Integral
x = Symbol('x')
p = exp(-(x - 10)**2/2)/sqrt(2*pi)
Integral(p, (x, 11, 12)).doit().evalf()
# Out:
# 0.135905121983278
